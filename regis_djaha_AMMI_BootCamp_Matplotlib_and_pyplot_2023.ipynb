# %% [markdown]
# <a href="https://colab.research.google.com/github/RegisKonan/FinalProject/blob/main/regis_djaha_AMMI_BootCamp_Matplotlib_and_pyplot_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![](https://matplotlib.org/3.1.0/_static/logo2.png)

# %% [markdown]
# # *Introduction*
#
# Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python.
#
# Humans are very visual creatures: we understand things better when we visualize them. However, the step to presenting analyses, results or insights can be a bottleneck: you might not even know where to start from or you might have already the right format in mind, but then questions like “Is this the right visual insights I want to bring to my audience?” will have definitely cross your mind.

# %% [markdown]
# # *Pyplot*
# Most of the plotting functionalities lay under the pyplot submodule, which is usually imported under the plt alias:

# %%
# Now the Pyplot package can be referred to as plt.
import matplotlib.pyplot as plt
import matplotlib
# set the defulat figure size
matplotlib.rcParams['figure.figsize'] = (15, 10)

# %% [markdown]
# # Simple Plots

# %% [markdown]
# ## Line plots

# %%
# we define our x-axis values and the corresponding y values, 
# they should contain the same number of element
x = [1, 2, 3, 4]
# y = 2x
y = [2, 4, 6, 8]
plt.plot(x, y)
plt.show()

# %%
# we can also plot any single variable function defined with numpy
import numpy as np
# define the domain
x = np.arange(-1, 10.1, 0.1)
# y=sin(x)
y = np.sin(x)
plt.plot(x, y)
plt.show()

# %% [markdown]
# ### Practise time
# Plot the exponential fucntion using numpy, the domain should be in the range (-10, 10) including 10

# %%
####### Add your code here #######
# define the x values
# define the y values
# use the plot function
x=np.arange(-10,10,0.1)
y=np.exp(x)

plt.plot(x,y,"r+")
# x title
plt.xlabel("X-axis")
# y title
plt.ylabel("Y-axis")
plt.legend(['exponential function'])
####### Add your code here #######
plt.show()

# %% [markdown]
# ## Multiple Line Points
# You can plot as many points as you like, just make sure you have the same number of points in both axes.

# %%
x = np.arange(-1, 10.1, 0.1)
sin_x = np.sin(x)
cos_x = np.cos(x)
# we pass the x values and y values for each function we want to plot
plt.plot(x, sin_x, x, cos_x)
plt.show()

# %% [markdown]
# ### Practise time
# Plot the exponential and the logarthmic fucntions using numpy, the domain should be in the range (0, 2) including 2

# %%
####### Add your code here #######
# define the x values
# define the y values for the exponential function
# define the y values for the logarthmic function
# use the plot function
x=np.linspace(0,2,100)
y_1=np.exp(x)
y_2=np.log(x)
plt.plot(x,y_1,'r',linewidth=10)
plt.plot(x,y_2,'y',linewidth=10)
plt.legend(['exp','log'])
####### Add your code here #######
plt.show()
# Fun math fact: the exponential and the logarthmic fucntions are inverse to each other, https://en.wikipedia.org/wiki/Inverse_function
# Out:
# <ipython-input-28-46fe974ad7da>:8: RuntimeWarning: divide by zero encountered in log
#   y_2=np.log(x)

# %% [markdown]
# ## Scatter plots

# %%
#### create a fake dataset ###
x = np.arange(50)
y = np.arange(50) + 10 * np.random.randn(50)
#### create a fake dataset ###
plt.scatter(x, y)
plt.show()

# %% [markdown]
# ## Histograms

# %%
# Generate some data from a guassian distribution
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)
# Plot the histogram
plt.hist(x, bins=50), # you can play with the bins size and observe the effect
plt.show()

# %%
from scipy.stats import norm, poisson, binom
n=25
p=0.1
i=np.arange(26)
BIN=binom.pmf(i,n,p)
plt.bar(i,BIN)
# Out:
# <BarContainer object of 26 artists>

# %% [markdown]
# ## Barplot

# %%
# Mostly used for Categorical variables
x = ["Cat", "Dog", "Fish"] # These can be for example be Cat, Dog, Fish
y = [34, 3, 100] # These numbers could be the sample size per category
plt.bar(x, y)
plt.show()

# %% [markdown]
# # Plot style

# %% [markdown]
# ## Adding Marekers

# %%
# Plain plot
x = [1, 2, 3, 4]
y = [2, 4, 6, 8]
plt.plot(x, y)
plt.show()

# %%
# To add a marker we use the keyword argument "marker" 
# and pass the marker type.
# All avalible markers https://matplotlib.org/stable/api/markers_api.html
plt.plot(x, y, marker="o")
plt.show()

# %%
# we can change the marker size and color using the keyword arguments markersize and markerfacecolor respectively
# List of colors and their format is avalible in https://matplotlib.org/stable/tutorials/colors/colors.html
# examples: 'r': red, 'g': green, 'b': blue
plt.plot(x, y, marker="o", markersize=20, markerfacecolor="g", markeredgecolor="y")
plt.show()

# %% [markdown]
# ## Line style and color

# %%
# We can change the line color using the keyword arguemnt "color"
# The list of colors is avalible in https://matplotlib.org/stable/gallery/color/named_colors.html
plt.plot(x, y, color="g")
plt.show()

# %%
# we can also change the line style using the keyword arguemnt "linestyle"
# different line styles are avalible in https://matplotlib.org/stable/gallery/lines_bars_and_markers/linestyles.html
# examples: dashed, dotted
plt.plot(x, y, color="g", linestyle="dotted")
plt.show()

# %% [markdown]
# ## Practise time
# Plot the figure below, the values you need are defined below:
# - The x range is from -10 to 10 with a step size of 1.
# - The function is X**2 (the quadratic function)
# - The marker value is "x".
# - the markeredge color is red.
# - Marker size is 10.
# - The curve color is black.
#
# **Hint**: look up the symbol of red and black in this link https://matplotlib.org/stable/gallery/color/named_colors.html)

# %% [markdown]
# ![index.png](data:image/png;base64,...)

# %%
####### Add your code here #######
# define the x values
# define the y values for the quadratic function
# use the plot function with the given parameters
x=np.arange(-10,10,1)
y=x**2
plt.plot(x,y,color='k',marker='x', markersize=10, markerfacecolor="r", markeredgecolor="r")

####### Add your code here #######
plt.show()

# %% [markdown]
# #*Create Title and Labels for a Plot*

# %% [markdown]
# ![2023-02-27 23.47.43.jpg](data:image/jpeg;base64,...)

# %%
# you can add a title, x and y label using plt.title, plt.x_label, plt.y_label respectively. 
# define the x values
x = np.arange(0, 10, 0.1)
# define the function
y = np.exp(x)
# create the plot
plt.plot(x, y)

# you can set the font parameters with the following dict and pass it to each label function through the fontdict argument
labels_font = {'family':'serif','color':'blue','size':20}
# plot title 
plt.title("Exponential Function",  fontdict=labels_font)
# x title
plt.xlabel("Time", fontdict=labels_font)
# y title
plt.ylabel("Growth Rate", fontdict=labels_font)
plt.show()

# %% [markdown]
# ## Adding a label in multiline plot

# %%
# you can add a title, x and y label using plt.title, plt.x_label, plt.y_label respectively. 
# define the x values
x = np.arange(0, 10, 0.1)
# define the function
y1 = np.cos(x)
y2 = np.sin(x)
# create the plot
plt.plot(x, y1, label="cos(x)" )
plt.plot(x, y2, label="sin(x)" )
# to show the label use plt.legends
plt.legend()
# you can set the font parameters with the following dict and pass it to each label function through the fontdict argument
labels_font = {'family':'serif','color':'blue','size':20}
# plot title 
plt.title("Sinusoids",  fontdict=labels_font)
# x title
plt.xlabel("X Values", fontdict=labels_font)
# y title
plt.ylabel("Functioin Values", fontdict=labels_font)
plt.show()

# %% [markdown]
# #*Multiple plots in one figure:*
# The subplots() function takes three arguments that describes the layout of the figure.
#
# The layout is organized in rows and columns, which are represented by the first and second argument.
#
# The third argument represents the index of the current plot.

# %% [markdown]
# ## Example 1

# %%
# Plot 1:
x = np.arange(-2, 5, 0.1)
cos_x = np.cos(x)

plt.subplot(1, 2, 1)  # The figure has 1 row, 2 columns, and this plot is the first plot.
plt.plot(x, cos_x, color="blue", linewidth=2.5)

# Plot 2:
sin_x = np.sin(x)

plt.subplot(1, 2, 2) #the figure has 1 row, 2 columns, and this plot is the second plot.
plt.plot(x, sin_x, color="red",  linewidth=2.5)

plt.show()

# %% [markdown]
# ## Example 2

# %%
# Plot 1:
x = np.arange(-2, 5, 0.1)
cos_x = np.cos(x)

plt.subplot(2, 1, 1)  # The figure has 2 row, 1 column, and this plot is the first plot.
plt.plot(x, cos_x, color="blue", linewidth=2.5)

# Plot 2:
sin_x = np.sin(x)

plt.subplot(2, 1, 2) #the figure has 2 row, 1 column, and this plot is the second plot.
plt.plot(x, sin_x, color="red",  linewidth=2.5)
plt.show()

# %%
# Draw 4 subplots (2 rows and 2 columns) and a title to each one
# Choose any function you want
###############################################################################

####### Add your code here #######
# define the x and y values for the subplot
# use plt.subplot to specify the layout and the index
# plot the function and add the title
# use the plot function with the given parameters
t=np.linspace(0,1,100)
# Plot 1:
x=np.exp(t)

plt.subplot(2, 2, 1) 
plt.plot(t, x, color="blue", linewidth=2.5)
plt.legend(['exp'])
# Plot 2:
y=t**3

plt.subplot(2, 2, 2) 
plt.plot(t, y, color="y", linewidth=2.5)
plt.legend(['t^3'])
# Plot 3:
z=1/(t+1)

plt.subplot(2, 2, 3) 
plt.plot(t, z, color="r", linewidth=2.5)
plt.legend(['inv'])
# Plot 4:
p=np.sqrt(t)

plt.subplot(2, 2, 4) 
plt.plot(t, p, color="g", linewidth=2.5)
plt.legend(['root'])
####### Add your code here #######

# If you want, you can add a main/super title to the figure using plt.suptitle("title")
plt.suptitle("function")
plt.show()
###############################################################################

# %% [markdown]
# #*Working with image*

# %%
# load and show images
# Importing image data into Numpy arrays
image_link = 'https://matplotlib.org/3.1.0/_static/logo2.png'
# read image
image = plt.imread(image_link)
# show image
plt.imshow(image)
plt.show()
# Out:
# <ipython-input-79-89268ff42346>:5: MatplotlibDeprecationWarning: Directly reading images from URLs is deprecated since 3.4 and will no longer be supported two minor releases later. Please open the URL for reading and pass the result to Pillow, e.g. with ``np.array(PIL.Image.open(urllib.request.urlopen(url)))``.
#   image = plt.imread(image_link)

# %%
# save images
plt.imsave("logo.png", image)

# %% [markdown]
# #Summary
#
# * plot(x-axis values, y-axis values) — plots a simple line graph with x-axis values against y-axis values
#
# * show() — displays the graph
# * title(“string”) — set the title of the plot as specified by the string
# * xlabel(“string”) — set the label for x-axis as specified by the string
# * ylabel(“string”) — set the label for y-axis as specified by the string
# * subplot(nrows, ncols, index) — Add a subplot to the current figure
# * suptitle(“string”) — It adds a common title to the figure specified by the string
# * subplots(nrows, ncols, figsize) — a convenient way to create subplots, in a single call. It returns a tuple of a figure and number of axes.
# * bar(categorical variables, values, color) — used to create vertical bar graphs
# * legend(loc) — used to make legend of the graph
# * hist(values, number of bins) — used to create a histogram
# * scatter(x-axis values, y-axis values) — plots a scatter plot with x-axis values against y-axis values
# *axes() — adds an axes to the current figure

# %% [markdown]
# #*Refrences*
#
# * https://www.w3schools.com/python/matplotlib_intro.asp
# * https://towardsdatascience.com/matplotlib-tutorial-learn-basics-of-pythons-powerful-plotting-library-b5d1b8f67596

# %% [markdown]
# # Extra Material
# Extra material could be useful in some cases

# %% [markdown]
# ## Matplotlib Application Interfaces (APIs)
# You need to check this if you want to understand the rest of the extra material.
# https://matplotlib.org/stable/users/explain/api_interfaces.html#api-interfaces

# %% [markdown]
# ## Plotting one plot inside another in the same figure

# %%
import math
x = np.arange(0, math.pi*2, 0.05)
fig=plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # main axes
axes2 = fig.add_axes([0.55, 0.55, 0.3, 0.3]) # inset axes

y = np.sin(x)
axes1.plot(x, y, 'b')

axes2.plot(x,np.cos(x),'r')

axes1.set_title('sine')
axes2.set_title("cosine")

plt.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.plot([1,2,3])
ax2 = fig.add_subplot(221, facecolor='y')
ax2.plot([1,2,3])

# %% [markdown]
# ## More Detailed Introduction
# This is a more comprehensive introduction in the pyplot documentation, it is useful if you want to know more details about how pyplot works.[link text](https://)
# https://matplotlib.org/stable/tutorials/introductory/quick_start.html#sphx-glr-tutorials-introductory-quick-start-py

# %% [markdown]
# # **Exercises**
# The goal of these exercises is to force you to search about material you do not know (just write what do you want in google and check the results in stackoverflow or the documentation).
# For example in the first exercises, you need to search about how to change the legend location

# %% [markdown]
# ## *Exercise 1*
# Create a figure with two subplots (2 rows and a single column)
# Draw two line plots in the top subplot, one green and one orange.
# Add a legend for the top plot, with labels "Green" and "Orange". Put this legend in the top-middle of graph.
# In the bottom subplot, create a scatter plot using any datapoint pair.

# %%
# Before we start anything, let's create some sample data for our plotting.
import numpy as np
import pandas as pd
df = pd.DataFrame(data={'a':np.random.randint(0, 100, 30),
                        'b':np.random.randint(0, 100, 30),
                        'c':np.random.randint(0, 100, 30)})
df.head()
# Out:
#     a   b   c
# 0  47  51  94
# 1  43  67  90
# 2  55  18  88
# 3  73   2  23
# 4  76  16  17

# %%
line1 = df['a'].to_numpy()
line2 = df['b'].to_numpy()
x = np.arange(line2.shape[0])
####### Add your code here #######
plt.subplot(2,1,1)
plt.plot(x,line1, 'g',line2,'orange')
plt.legend(['Green','Orange'], loc='upper center')
# you can set the font parameters with the following dict and pass it to each label function through the fontdict argument
plt.subplot(2,1,2)
plt.scatter(line1,line2)
plt.xlabel('line1')
plt.ylabel('line2')
plt.title('Scatter Plot')
####### Add your code here #######
plt.show()

# %% [markdown]
# ## *Exercise 2*
# Create a figure with three subplots, aligned vertically.
# Create a bar graph for a and b on the first two, but at the last one draw both a and b, but put b on top of a! (Hint: use the bottom argument in the bar function)
# Make sure the color for a and b are consistent in all the subplots!
# Extra Challenge: Write the magnitude of each bar on top of it

# %%
a = df['a'].to_numpy()
b = df['b'].to_numpy()

####### Add your code here #######
#fig, axs = plt.subplots(nrows=3, ncols=1, figsize=(15, 10))
plt.subplot(3,1,1)
plt.bar(x,a, color='y')
plt.legend(['a'])
for i, v in enumerate(a):
    plt.text(i, v, str(v), ha='center', va='bottom')
plt.subplot(3,1,2)
plt.bar(x,b, color='r')
plt.legend(['b'])
for i, v in enumerate(b):
    plt.text(i, v, str(v), ha='center', va='bottom')
plt.subplot(3,1,3)
plt.bar(x, a, 0.5, color='y')
plt.bar(x, b,0.5,bottom=a, color='r')
for i, v in enumerate(a):
    plt.text(i, v/2, str(v), ha='center', va='bottom')
for i, v in enumerate(b):
    plt.text(i, v+a[i]/2, str(v), ha='center', va='bottom')
####### Add your code here #######
plt.legend(['a','b'])
plt.show()

# %% [markdown]
# ## *Exercise 3*
# Create the following plot, you will need to search about how to make the y-axis in a log, symlog, and logit scales, also search about how to show the grid in each subplot.
# The functios form is as follows:
# -

# %% [markdown]
# ![Screen Shot 2023-02-28 at 06.28.37.png](data:image/png;base64,...)

# %%
# make up some data in the open interval (0, 3), this data should fixed you only need to the change the scale of the y axis
x = np.arange(0, 3, 0.1)
y = np.arange(0, 3, 0.1)

####### Add your code here #######
# Plot 1:

plt.subplot(2,2,1)
plt.plot(x,y)
plt.xscale('linear')
plt.title('linear')
plt.grid(True)

# Plot 2:
plt.subplot(2,2,2)
plt.plot(x, y)
plt.yscale('log')
plt.title('log')
plt.grid(True)

# Plot 3:
plt.subplot(2,2,3)
plt.plot(x, y - y.mean())
plt.yscale('symlog',linthresh=0.01)
plt.title('symlog')
plt.grid(True)

# Plot 4:
plt.subplot(2,2,4)
plt.plot(x, y)
plt.yscale('logit')
plt.title('logit')
plt.grid(True)



####### Add your code here #######


plt.show()
